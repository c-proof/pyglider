# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
with xr.open_dataset('L0-timeseries/dfo-rosie713-20190615.nc') as ds:
    display(ds)
    fig, ax = plt.subplots()
    ds['SIGMA0'].plot(ax=ax)
    print(ds.data_vars)
# Out:
# <xarray.Dataset> Size: 215kB
# Dimensions:                (N_MEASUREMENTS: 1167)
# Coordinates:
#     TIME                   (N_MEASUREMENTS) datetime64[ns] 9kB ...
# Dimensions without coordinates: N_MEASUREMENTS
# Data variables: (12/22)
#     LATITUDE               (N_MEASUREMENTS) float64 9kB ...
#     LONGITUDE              (N_MEASUREMENTS) float64 9kB ...
#     CNDC                   (N_MEASUREMENTS) float64 9kB ...
#     TEMP                   (N_MEASUREMENTS) float64 9kB ...
#     PRES                   (N_MEASUREMENTS) float64 9kB ...
#     HEADING                (N_MEASUREMENTS) float64 9kB ...
#     ...                     ...
#     PSAL                   (N_MEASUREMENTS) float64 9kB ...
#     POTENTIAL_TEMPERATURE  (N_MEASUREMENTS) float64 9kB ...
#     SIGMA0                 (N_MEASUREMENTS) float64 9kB ...
#     DENSITY                (N_MEASUREMENTS) float64 9kB ...
#     PROFILE_NUMBER         (N_MEASUREMENTS) float64 9kB ...
# ...
